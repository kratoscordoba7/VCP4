# %% [markdown]
# #Paquetes necesarios

# %%
import cv2  
import math 
from ultralytics import YOLO
# Out:
# WARNING  Python>=3.10 is required, but Python==3.9.20 is currently installed

# %% [markdown]
# Modelos preentrenados, visualizando con las utilidades de ultralytics

# %%
# NO ARRANCAR ESTA MIERDA
# Carga del modelo
#model = YOLO('yolo11n.pt') #Contenedores
#model = YOLO('yolo11n-seg.pt') #Máscaras
model = YOLO('yolo11n-pose.pt')  #Pose

#Para un vídeo 
filename = "TGC23_PdH_C0056cut.mp4"
results = model(filename, show=True)

cv2.destroyAllWindows()
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 134.3ms
# video 1/1 (frame 2/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 59.8ms
# video 1/1 (frame 3/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 54.2ms
# video 1/1 (frame 4/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 52.0ms
# video 1/1 (frame 5/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 48.0ms
# video 1/1 (frame 6/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 49.0ms
# video 1/1 (frame 7/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 8/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 48.0ms
# video 1/1 (frame 9/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 48.4ms
# video 1/1 (frame 10/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 52.1ms
# video 1/1 (frame 11/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 51.4ms
# video 1/1 (frame 12/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 48.0ms
# video 1/1 (frame 13/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 14/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 47.2ms
# video 1/1 (frame 15/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 46.0ms
# video 1/1 (frame 16/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 47.0ms
# video 1/1 (frame 17/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 49.5ms
# video 1/1 (frame 18/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 50.1ms
# video 1/1 (frame 19/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 46.0ms
# video 1/1 (frame 20/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 49.2ms
# video 1/1 (frame 21/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 47.7ms
# video 1/1 (frame 22/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 23/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 42.0ms
# video 1/1 (frame 24/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.1ms
# video 1/1 (frame 25/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 40.0ms
# video 1/1 (frame 26/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 27/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 28/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 42.5ms
# video 1/1 (frame 29/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 48.0ms
# video 1/1 (frame 30/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.3ms
# video 1/1 (frame 31/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.0ms
# video 1/1 (frame 32/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 46.0ms
# video 1/1 (frame 33/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 43.0ms
# video 1/1 (frame 34/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.8ms
# video 1/1 (frame 35/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 43.0ms
# video 1/1 (frame 36/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 47.1ms
# video 1/1 (frame 37/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 38/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 39/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.5ms
# video 1/1 (frame 40/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 57.0ms
# video 1/1 (frame 41/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 51.8ms
# video 1/1 (frame 42/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.0ms
# video 1/1 (frame 43/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 44/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.0ms
# video 1/1 (frame 45/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.0ms
# video 1/1 (frame 46/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 47/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 43.0ms
# video 1/1 (frame 48/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 62.0ms
# video 1/1 (frame 49/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 55.1ms
# video 1/1 (frame 50/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 52.0ms
# video 1/1 (frame 51/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 52.2ms
# video 1/1 (frame 52/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 47.0ms
# video 1/1 (frame 53/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 47.0ms
# video 1/1 (frame 54/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 47.0ms
# video 1/1 (frame 55/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 47.0ms
# video 1/1 (frame 56/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 46.0ms
# video 1/1 (frame 57/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.0ms
# video 1/1 (frame 58/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 46.0ms
# video 1/1 (frame 59/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections),
375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 350/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 46.0ms
# video 1/1 (frame 351/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 42.0ms
# video 1/1 (frame 352/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 353/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 46.0ms
# video 1/1 (frame 354/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 46.1ms
# video 1/1 (frame 355/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.0ms
# video 1/1 (frame 356/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 46.0ms
# video 1/1 (frame 357/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 47.0ms
# video 1/1 (frame 358/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 46.0ms
# video 1/1 (frame 359/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.0ms
# video 1/1 (frame 360/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 47.3ms
# video 1/1 (frame 361/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 362/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 45.0ms
# video 1/1 (frame 363/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.0ms
# video 1/1 (frame 364/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 48.1ms
# video 1/1 (frame 365/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.0ms
# video 1/1 (frame 366/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 46.1ms
# video 1/1 (frame 367/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 47.3ms
# video 1/1 (frame 368/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 47.0ms
# video 1/1 (frame 369/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.3ms
# video 1/1 (frame 370/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 43.0ms
# video 1/1 (frame 371/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 48.0ms
# video 1/1 (frame 372/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 49.0ms
# video 1/1 (frame 373/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 44.0ms
# video 1/1 (frame 374/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 48.0ms
# video 1/1 (frame 375/375) c:\Users\gatete\anaconda3\envs\VC_P4\VCP4\TGC23_PdH_C0056cut.mp4: 384x640 (no detections), 46.2ms
# Speed: 1.7ms preprocess, 46.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# Desde cámara, detección con yolo11, modelo nano. Visualización propia con OpenCV

# %%
# Carga del modelo, descarga en disco si no está presente en la carpeta
model = YOLO('yolo11n.pt') #Contenedores

# Etiqueta de las distintas clases
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


# Captura desde la webcam
vid = cv2.VideoCapture(0)
  
while(True):      
    # fotograma a fotograma
    ret, img = vid.read()
  
    # si hay imagen válida
    if ret:  
        # Detecta en la imagen
        results = model(img, stream=True)
        
        # Para cada detección
        for r in results:
            boxes = r.boxes

            for box in boxes:
                # Contenedor
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values
                
                # Confianza
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confianza --->",confidence)

                # Clase
                cls = int(box.cls[0])
                print("Clase -->", classNames[cls])

                # Convierte identificador numérico de clase a un color RGB
                escala = int((cls / len(classNames)) * 255 * 3)
                if escala >= 255*2:
                    R = 255
                    G = 255
                    B = escala - 255*2
                else:
                    if escala >= 255:
                        R = 255
                        G = escala - 255
                        B = 0
                    else:
                        R = escala
                        G = 0
                        B = 0

                # Dibuja el contenedor y clase
                cv2.rectangle(img, (x1, y1), (x2, y2), (R, G, B), 3)
                cv2.putText(img, classNames[cls] , [x1, y1], cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, B), 2)

        # Muestra fotograma
        cv2.imshow('Vid', img)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# 0: 480x640 5 persons, 1 tv, 195.5ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.7
# Clase --> person
# Confianza ---> 0.38
# Clase --> person
# Confianza ---> 0.36
# Clase --> person
# Confianza ---> 0.27
# Clase --> person
# Confianza ---> 0.27
# Clase --> tvmonitor
# Speed: 6.0ms preprocess, 195.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 tv, 196.3ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.69
# Clase --> person
# Confianza ---> 0.49
# Clase --> person
# Confianza ---> 0.38
# Clase --> person
# Confianza ---> 0.3
# Clase --> tvmonitor
# Confianza ---> 0.28
# Clase --> person
# Speed: 4.0ms preprocess, 196.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 tv, 149.6ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.72
# Clase --> person
# Confianza ---> 0.48
# Clase --> person
# Confianza ---> 0.4
# Clase --> person
# Confianza ---> 0.32
# Clase --> tvmonitor
# Confianza ---> 0.31
# Clase --> chair
# Speed: 4.0ms preprocess, 149.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 chair, 1 tv, 170.6ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.67
# Clase --> person
# Confianza ---> 0.46
# Clase --> person
# Confianza ---> 0.36
# Clase --> chair
# Confianza ---> 0.32
# Clase --> tvmonitor
# Speed: 2.0ms preprocess, 170.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 tv, 176.3ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.7
# Clase --> person
# Confianza ---> 0.4
# Clase --> chair
# Confianza ---> 0.39
# Clase --> tvmonitor
# Confianza ---> 0.38
# Clase --> person
# Confianza ---> 0.38
# Clase --> person
# Confianza ---> 0.28
# Clase --> person
# Speed: 4.0ms preprocess, 176.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 tv, 145.4ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.69
# Clase --> person
# Confianza ---> 0.45
# Clase --> person
# Confianza ---> 0.42
# Clase --> person
# Confianza ---> 0.37
# Clase --> tvmonitor
# Confianza ---> 0.3
# Clase --> person
# Confianza ---> 0.29
# Clase --> chair
# Speed: 4.0ms preprocess, 145.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 tv, 140.7ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.73
# Clase --> person
# Confianza ---> 0.58
# Clase --> person
# Confianza ---> 0.45
# Clase --> chair
# Confianza ---> 0.37
# Clase --> tvmonitor
# Confianza ---> 0.29
# Clase --> person
# Confianza ---> 0.26
# Clase --> person
# Speed: 2.0ms preprocess, 140.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 2 tvs, 150.4ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.69
# Clase --> person
# Confianza ---> 0.48
# Clase --> person
# Confianza ---> 0.46
# Clase --> person
# Confianza ---> 0.45
# Clase --> person
# Confianza ---> 0.43
# Clase --> tvmonitor
# Confianza ---> 0.38
# Clase --> chair
# Confianza ---> 0.36
# Clase --> person
# Confianza ---> 0.33
# Clase --> tvmonitor
# Speed: 3.0ms preprocess, 150.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 7 persons, 1 chair, 2 tvs, 128.1ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.72
# Clase --> person
# Confianza ---> 0.51
# Clase --> person
# Confianza ---> 0.42
# Clase --> person
# Confianza ---> 0.42
# Clase --> tvmonitor
# Confianza ---> 0.38
# Clase --> person
# Confianza ---> 0.36
# Clase --> person
# Confianza ---> 0.36
# Clase --> chair
# Confianza ---> 0.36
# Clase --> tvmonitor
# Confianza ---> 0.26
# Clase --> person
# Speed: 2.0ms preprocess, 128.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 2 tvs, 132.6ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.7
# Clase --> person
# Confianza ---> 0.47
# Clase --> person
# Confianza ---> 0.4
# Clase --> person
# Confianza ---> 0.36
# Clase --> chair
# Confianza ---> 0.29
# Clase --> tvmonitor
# Confianza ---> 0.26
# Clase --> tvmonitor
# Speed: 3.0ms preprocess, 132.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 suitcase, 1 chair, 185.9ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.7
# Clase --> person
# Confianza ---> 0.53
# Clase --> person
# Confianza ---> 0.34
# Clase --> chair
# Confianza ---> 0.32
# Clase --> person
# Confianza ---> 0.28
# Clase --> suitcase
# Speed: 2.0ms preprocess, 185.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 tv, 156.2ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.72
# Clase --> person
# Confianza ---> 0.44
# Clase --> person
# Confianza ---> 0.38
# Clase --> tvmonitor
# Confianza ---> 0.28
# Clase --> person
# Speed: 2.0ms preprocess, 156.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 tv, 136.9ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.71
# Clase --> person
# Confianza ---> 0.42
# Clase --> tvmonitor
# Confianza ---> 0.35
# Clase --> chair
# Confianza ---> 0.34
# Clase --> person
# Confianza ---> 0.3
# Clase --> person
# Confianza ---> 0.28
# Clase --> person
# Speed: 3.0ms preprocess, 136.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 2 tvs, 146.6ms
# Confianza ---> 0.86
# Clase --> person
# Confianza ---> 0.68
# Clase --> person
# Confianza ---> 0.49
# Clase --> person
# Confianza ---> 0.49
# Clase --> person
# Confianza ---> 0.47
# Clase --> tvmonitor
# Confianza ---> 0.35
# Clase --> chair
# Confianza ---> 0.31
# Clase --> tvmonitor
# Speed: 2.0ms preprocess, 146.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 2 tvs, 141.6ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.65
# Clase --> person
# Confianza ---> 0.49
# Clase --> person
# Confianza ---> 0.42
# Clase --> person
# Confianza ---> 0.37
# Clase --> person
# Confianza ---> 0.36
# Clase --> chair
# Confianza ---> 0.35
# Clase --> tvmonitor
# Confianza ---> 0.33
# Clase --> person
# Confianza ---> 0.27
# Clase --> tvmonitor
# Speed: 4.0ms preprocess, 141.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 1 suitcase, 1 chair, 2 tvs, 167.6ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.54
# Clase --> person
# Confianza ---> 0.39
# Clase --> chair
# Confianza ---> 0.36
# Clase --> tvmonitor
# Confianza ---> 0.34
# Clase --> person
# Confianza ---> 0.31
# Clase --> tvmonitor
# Confianza ---> 0.26
# Clase --> suitcase
# Speed: 3.8ms preprocess, 167.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 1 chair, 1 tv, 187.7ms
# Confianza ---> 0.87
# Clase --> person
# Confianza ---> 0.51
# Clase --> person
# Confianza ---> 0.41
# Clase --> person
# Confianza ---> 0.31
# Clase --> chair
# Confianza ---> 0.3
# Clase --> person
# Confianza ---> 0.28
# Clase --> tvmonitor
# Speed: 4.0ms preprocess, 187.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 suitcase, 1 chair, 1 tv, 156.9ms
# Confianza ---> 0.88
# Clase --> person
# Confianza ---> 0.64
# Clase --> person
# Confianza ---> 0.54
# Clase --> person
# Confianza ---> 0.37
# Clase --> person
# Confianza ---> 0.35
# Clase --> person
# Confianza ---> 0.35
# Clase --> tvmonitor
# Confianza ---> 0.28
# Clase --> chair
# Confianza ---> 0.26
# Clase --> suitcase
# Confianza ---> 0.26
# Clase --> person
# Speed: 3.0ms preprocess, 156.9ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 8 persons, 1 chair, 2 tvs, 157.2ms
# Confianza ---> 0.88
# Clase --> person
# Confianza ---> 0.73
# Clase --> person
# Confianza ---> 0.49
# Clase --> person
# Confianza ---> 0.47
# Clase --> tvmonitor
# Confianza ---> 0.43
# Clase --> tvmonitor
# Confianza ---> 0.43
# Clase --> person
# Confianza ---> 0.4
# Clase --> person
# Confianza ---> 0.35
# Clase --> person
# Confianza ---> 0.32
# Clase --> chair
# Confianza ---> 0.28
# Clase --> person
# Confianza ---> 0.26
# Clase --> person
# Speed: 2.0ms preprocess, 157.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# Seguimiento. Requiere instalar lap con pip install lap

# %%
from collections import defaultdict
import numpy as np

# Carga del modelo, descarga en disco si no está presente en la carpeta
model = YOLO('yolo11n.pt') #Contenedores

# Etiqueta de las distintas clases
classNames = ["person", "bicycle", "car"]


# Captura desde la webcam
vid = cv2.VideoCapture(0)
track_history = defaultdict(lambda: [])
  
while(True):      
    # fotograma a fotograma
    ret, img = vid.read()
  
    # si hay imagen válida
    if ret:  
        # Seguimiento, con persistencia entre fotogramas
        results = model.track(img, persist=True, classes = [0,1,2])

        if 0:
            if results is not None:
                print(results[0])
                boxes = results[0].boxes.xywh.cpu()
                track_ids = results[0].boxes.id.int().cpu().tolist()
                annotated_frame = results[0].plot()
                for box, track_id in zip(boxes, track_ids):
                    x, y, w, h = box
                    track = track_history[track_id]
                    track.append((float(x), float(y)))
                    if len(track) > 30:
                        track.pop(0)
                    points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
                    cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)
                cv2.imshow("YOLO11 Tracking", annotated_frame)
                if cv2.waitKey(1) & 0xFF == ord("q"):
                    break
        

        
        # Para cada detección
        for r in results:
            boxes = r.boxes

            for box in boxes:
                # Contenedor
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

                #Etiqueta de seguimiento
                if box.id is not None:
                    track_id = str(int(box.id[0].tolist()))
                else:
                    track_id = ''
                
                # Confianza
                confidence = math.ceil((box.conf[0]*100))/100
                print("Confianza --->",confidence)

                # Clase
                cls = int(box.cls[0])
                print("Clase -->", classNames[cls])

                # Convierte identificador numérico de clase a un color RGB
                escala = int((cls / len(classNames)) * 255 * 3)
                if escala >= 255*2:
                    R = 255
                    G = 255
                    B = escala - 255*2
                else:
                    if escala >= 255:
                        R = 255
                        G = escala - 255
                        B = 0
                    else:
                        R = escala
                        G = 0
                        B = 0

                # Dibuja el contenedor y clase
                cv2.rectangle(img, (x1, y1), (x2, y2), (R, G, B), 3)
                cv2.putText(img, track_id + ' ' + classNames[cls] , [x1, y1], cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, B), 2)

        # Muestra fotograma
        cv2.imshow('Vid', img)
    
    # Detenemos pulsado ESC
    if cv2.waitKey(20) == 27:
        break
  
# Libera el objeto de captura
vid.release()
# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# 0: 480x640 (no detections), 84.5ms
# Speed: 4.0ms preprocess, 84.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.1ms
# Speed: 1.0ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.8ms
# Speed: 1.0ms preprocess, 52.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.5ms
# Speed: 1.0ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 51.0ms
# Speed: 1.0ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 46.0ms
# Speed: 1.0ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.0ms
# Speed: 2.0ms preprocess, 48.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 48.5ms
# Speed: 1.0ms preprocess, 48.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 52.6ms
# Speed: 1.0ms preprocess, 52.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 47.5ms
# Speed: 1.0ms preprocess, 47.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 59.2ms
# Speed: 1.0ms preprocess, 59.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 63.1ms
# Speed: 2.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)

# %%
from inference_sdk import InferenceHTTPClient
from collections import defaultdict
import numpy as np
import cv2
import base64

# Inicializa el cliente de inferencia
CLIENT = InferenceHTTPClient(
    api_url="https://detect.roboflow.com",
    api_key="wwc5TpbiPDQT2hBThzFI"
)

# Etiquetas de las distintas clases
classNames = ["person", "bicycle", "car"]

# Función para codificar la imagen a base64
def encode_image_to_base64(image):
    _, buffer = cv2.imencode('.jpg', image)
    jpg_as_text = base64.b64encode(buffer).decode('utf-8')
    return jpg_as_text

# Captura desde el archivo de video
vid = cv2.VideoCapture('video.mp4')
track_history = defaultdict(lambda: [])

while vid.isOpened():  # Verifica si el video se abrió correctamente
    # Leer fotograma a fotograma
    ret, img = vid.read()
  
    # Si hay un fotograma válido
    if ret:
        # Codificar la imagen en base64
        encoded_image = encode_image_to_base64(img)
        
        # Hacer la inferencia en el fotograma usando Roboflow
        response = CLIENT.infer(
            encoded_image,  # La imagen codificada como base64
            model_id="license-detector-k1lvk/1"
        )

        predictions = response.get("predictions", [])

        # Para cada predicción en el fotograma
        for prediction in predictions:
            # Coordenadas de la caja de detección
            x1 = int(prediction['x'] - prediction['width'] / 2)
            y1 = int(prediction['y'] - prediction['height'] / 2)
            x2 = int(prediction['x'] + prediction['width'] / 2)
            y2 = int(prediction['y'] + prediction['height'] / 2)

            # Clase de la detección
            cls = prediction.get('class', '')
            if cls in classNames:
                cls_index = classNames.index(cls)
            else:
                cls_index = -1  # No se reconoce la clase

            # Confianza
            confidence = round(prediction['confidence'], 2)
            print(f"Confianza ---> {confidence}")
            print(f"Clase ---> {cls}")

            # Dibuja la caja en el fotograma
            color = (0, 255, 0)  # Color verde
            if cls_index != -1:
                # Convierte el índice de clase en un color RGB
                escala = int((cls_index / len(classNames)) * 255 * 3)
                if escala >= 255 * 2:
                    R = 255
                    G = 255
                    B = escala - 255 * 2
                else:
                    if escala >= 255:
                        R = 255
                        G = escala - 255
                        B = 0
                    else:
                        R = escala
                        G = 0
                        B = 0
                color = (R, G, B)

            # Dibuja el contenedor y clase
            cv2.rectangle(img, (x1, y1), (x2, y2), color, 3)
            cv2.putText(img, f"{cls} {confidence}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

        # Muestra el fotograma
        cv2.imshow('Video Stream', img)
    
    # Detenemos si se pulsa ESC o cuando el video termine
    if cv2.waitKey(20) == 27:
        break

# Libera el objeto de captura y destruye ventanas
vid.release()
cv2.destroyAllWindows()

# %%
from inference_sdk import InferenceHTTPClient
import numpy as np
import cv2
import base64

# Inicializa el cliente de inferencia
CLIENT = InferenceHTTPClient(
    api_url="https://detect.roboflow.com",
    api_key="wwc5TpbiPDQT2hBThzFI"
)

# Etiquetas de las distintas clases
classNames = ["person", "bicycle", "car"]

# Función para codificar la imagen a base64
def encode_image_to_base64(image):
    _, buffer = cv2.imencode('.jpg', image)
    jpg_as_text = base64.b64encode(buffer).decode('utf-8')
    return jpg_as_text

# Cargar la imagen desde el archivo
img = cv2.imread('bugati_chiron_cr7.jpg')

# Verifica si la imagen se cargó correctamente
if img is not None:
    # Codificar la imagen en base64
    encoded_image = encode_image_to_base64(img)

    # Hacer la inferencia en la imagen usando Roboflow
    response = CLIENT.infer(
        encoded_image,  # La imagen codificada como base64
        model_id="license-detector-k1lvk/1"
    )

    predictions = response.get("predictions", [])

    # Para cada predicción en la imagen
    for prediction in predictions:
        # Coordenadas de la caja de detección
        x1 = int(prediction['x'] - prediction['width'] / 2)
        y1 = int(prediction['y'] - prediction['height'] / 2)
        x2 = int(prediction['x'] + prediction['width'] / 2)
        y2 = int(prediction['y'] + prediction['height'] / 2)

        # Clase de la detección
        cls = prediction.get('class', '')
        if cls in classNames:
            cls_index = classNames.index(cls)
        else:
            cls_index = -1  # No se reconoce la clase

        # Confianza
        confidence = round(prediction['confidence'], 2)
        print(f"Confianza ---> {confidence}")
        print(f"Clase ---> {cls}")

        # Dibuja la caja en la imagen
        color = (0, 255, 0)  # Color verde
        if cls_index != -1:
            # Convierte el índice de clase en un color RGB
            escala = int((cls_index / len(classNames)) * 255 * 3)
            if escala >= 255 * 2:
                R = 255
                G = 255
                B = escala - 255 * 2
            else:
                if escala >= 255:
                    R = 255
                    G = escala - 255
                    B = 0
                else:
                    R = escala
                    G = 0
                    B = 0
            color = (R, G, B)

        # Dibuja el contenedor y clase
        cv2.rectangle(img, (x1, y1), (x2, y2), color, 3)
        cv2.putText(img, f"{cls} {confidence}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

    # Muestra la imagen con las detecciones
    cv2.imshow('Image Detection', img)
    cv2.waitKey(0)  # Espera a que se pulse una tecla

else:
    print("Error al cargar la imagen.")

# Destruye ventanas
cv2.destroyAllWindows()
# Out:
# Confianza ---> 0.87
# Clase ---> cars-numberplate
# Confianza ---> 0.65
# Clase ---> cars-numberplate
# Confianza ---> 0.54
# Clase ---> license

# %% [markdown]
# Intregración con seguimiento (tracking)
# !!!!!!!!!Nota: he tenido que bajar a la versión de python 3.9.5 e instalar lap con pip install lap

# %%
## NO TOCAR POR DIOS!!!!!

# Carga del modelo
model = YOLO('yolo11n.pt') #Contenedores
#model = YOLO('yolov11n-seg.pt') #Máscaras
#model = YOLO('yolo11n-pose.pt')  #Pose

#Para un vídeo 
filename = "TGC23_PdH_C0056cut.mp4"
results = model.track(source=filename, show=True)  # BoT-SORT tracker (por defecto)
#results = model.track(source=filename, show=True, tracker="bytetrack.yaml")  # ByteTrack tracker

cv2.destroyAllWindows()

# %% [markdown]
# Reconocimiento de caracteres tras instalar pytesseract y tesseract

# %%
# NO EJECUTAR 
# Tesseract
import cv2
import pytesseract
from pytesseract import Output

# Previamente debes descargar los ejecutables
# Si la ruta de Tesseract no está en el PATH, ruta al ejecutable
pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract'

# Lenguajes disponibles
print(pytesseract.get_languages(config=''))

#Cargo imagen y ocnvierto a RGB
img = cv2.imread('ocr_test.tif') 

if img is not None:
    #Convierte a RGB antes de procesar
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    #Texto localizado
    print(pytesseract.image_to_string(img))

    #Texto y localización en imagen de cada palabra
    d = pytesseract.image_to_data(img_rgb, output_type=Output.DICT)

    n_boxes = len(d['text'])
    for i in range(n_boxes):
        #Nivel de confianza
        if int(d['conf'][i]) > 60:
            text = d['text'][i]
            conf = d['conf'][i]
            (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])
            img = cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

            print(f'Texto: {text} ({conf:.2f}%)\nContenedor: {x,y,x+w,y+h}')

    cv2.imshow('img', img_rgb)
    cv2.waitKey(-1)

   

else:
    print('Error de imagen')

# %% [markdown]
# Reconocimiento de caracteres tras instalar easyocr

# %%
import easyocr

#Carga del modelo de lengua
reader = easyocr.Reader(['es']) 

#Reconocimiento de una imagen
res = reader.readtext('ocr_test.tif')

for (bbox, text, prob) in res:
    # Coordenadas en orden 
    (top_left, top_right, bottom_right, bottom_left) = bbox
    print(f'\nTexto: {text}\nProbabilidad: {prob:.2f}\nContenedor: {tuple(map(int, top_left)),tuple(map(int, bottom_right))}')


#Con restricción de caracteres reconocibles
#result = reader.readtext('toy.tif', allowlist ='0123456789')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Texto: Hasta el infinito y más allá
# Probabilidad: 0.67
# Contenedor: ((49, 85), (617, 147))
